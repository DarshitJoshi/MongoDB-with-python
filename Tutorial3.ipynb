# %%
# !pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 140.3 kB/s eta 0:00:05
# ...

# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://127.0.0.1:27017/')

# %%
mydb = client['Employee']
information = mydb.employeeinformation

# %%
record = [{
    'firstname':'Darshit',
    'lastname':'Joshi',
    'department':'Analytics'
     },{
    'firstname':'Darshit1',
    'lastname':'Joshi1',
    'department':'Analytics1'
     },{
    'firstname':'Darshit3',
    'lastname':'Joshi3',
    'department':'Anakytics3'
     }]

# %%
information.insert_many(record)
# Out:
# InsertManyResult([ObjectId('6697b0fe9e14e265dc571bf8'), ObjectId('6697b0fe9e14e265dc571bf9'), ObjectId('6697b0fe9e14e265dc571bfa')], acknowledged=True)
